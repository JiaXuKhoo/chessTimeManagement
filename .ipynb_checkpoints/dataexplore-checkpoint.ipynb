# %%
import numpy as np
import pandas as pd
import maptlotlib.pyplot

# %%
data = pd.read_csv("pilot_bucket_data.csv")

# %%
data
# Out:
#                                                    fen  ref_nodes  \
# 0    r2q1rk1/ppp2ppp/2np1n2/2b1p3/4P1b1/1BPP1N2/PP3...    1600000
# 1    r2q1rk1/pp1nbppp/2p1pn2/3p1b2/2PP1B2/2N1PN2/PP...    1600000
# 2              2r5/8/7R/1P2kp2/2P1pp2/2K5/5PPP/8 b - -    1600000
# 3    4rrk1/R5bp/3qp1p1/3p3n/2pB1P2/5BPP/1P3P2/3QR1K...    1600000
# 4    2kr3r/ppp1n1pp/2nq1p2/8/3P2b1/1Q2BN2/PP2BPPP/R...    1600000
# ..                                                 ...        ...
# 995         4bk1r/4qppp/1p6/8/4B3/Q7/P4PP1/4R1K1 w - -    1600000
# 996  5rk1/1bpqb1pp/p7/1p1P4/4P3/1P6/PBQ1B2P/5RK1 w - -    1600000
# 997      5B1k/6R1/b4p1p/5P2/p1P5/1P6/P3r1PP/5RK1 w - -    1600000
# 998                   8/8/1K6/8/1p6/1N6/2p1k2P/8 w - -    1600000
# 999    2r3k1/4Rp1p/p5p1/1p6/1PbP4/2P2PB1/3K2PP/8 w - -    1600000
#
#     ref_bestmove  ref_cp  ref_depth  ref_seldepth bucket_50000_bestmove  \
# 0           h2h3    35.0         26            32                  h2h3
# ...
